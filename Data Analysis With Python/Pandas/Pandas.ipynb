# %% [markdown]
# ## Definition

# %% [markdown]
# ## Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series using list

# %%
# string
country=['Pakistan','India','USA','Qatr','Dubai']
pd.Series(country)
# Out:
# 0    Pakistan
# 1       India
# 2         USA
# 3        Qatr
# 4       Dubai
# dtype: str

# %%
# integers
runs=[23,45,68,90,123,256,23]
run_ser=pd.Series(runs)

# %% [markdown]
# ## Custom index

# %%
marks=[58,89,56,100]
subjects=['ICT','DLD','ENGLISH','OOP']
pd.Series(marks,index=subjects)
# Out:
# ICT         58
# DLD         89
# ENGLISH     56
# OOP        100
# dtype: int64

# %% [markdown]
# ## setting a name

# %%
marks=pd.Series(marks,index=subjects,name='Noman Marks')
marks
# Out:
# ICT         58
# DLD         89
# ENGLISH     56
# OOP        100
# Name: Noman Marks, dtype: int64

# %% [markdown]
# ## Series from dictionary

# %%
marks_dict = {
    "Mathematics": 85,
    "Computer Science": 92,
    "Physics": 78,
    "Chemistry": 83,
    "English": 88,
    "Data Science": 95,
    "Machine Learning": 90,
    "Operating Systems": 81,
    "Digital Logic Design": 87,
    "Technical Writing": 84
}
var=pd.Series(marks_dict,name=" Noman's Marks")
var
# Out:
# Mathematics             85
# Computer Science        92
# Physics                 78
# Chemistry               83
# English                 88
# Data Science            95
# Machine Learning        90
# Operating Systems       81
# Digital Logic Design    87
# Technical Writing       84
# Name:  Noman's Marks, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
# size
var.size
# Out:
# 10

# %%
# dtype
var.dtype
# Out:
# dtype('int64')

# %%
# name
var.name
# Out:
# " Noman's Marks"

# %%
# is_unique
var.is_unique
# Out:
# True

# %%
# index
var.index
# Out:
# Index(['Mathematics', 'Computer Science', 'Physics', 'Chemistry', 'English',
#        'Data Science', 'Machine Learning', 'Operating Systems',
#        'Digital Logic Design', 'Technical Writing'],
#       dtype='str')

# %%
run_ser
# Out:
# 0     23
# 1     45
# 2     68
# 3     90
# 4    123
# 5    256
# 6     23
# dtype: int64

# %%
run_ser.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# values
var.values
# Out:
# array([85, 92, 78, 83, 88, 95, 90, 81, 87, 84])

# %%
run_ser.values
# Out:
# array([ 23,  45,  68,  90, 123, 256,  23])

# %% [markdown]
# ## Series Read_csv

# %%
import pandas as pd
# Read the CSV and explicitly squeeze it into a Series
df=pd.read_csv('expenses_single_column.csv')
series=df.squeeze('columns')
series
# Out:
# 0     2114.0
# 1        NaN
# 2        NaN
# 3      709.0
# 4     3855.0
#        ...
# 57    5729.0
# 58    3434.0
# 59    2617.0
# 60    2893.0
# 61    1065.0
# Name: Expense_PKR, Length: 62, dtype: float64

# %%
type(series)
# Out:
# pandas.Series

# %%
df=pd.read_csv('expenses_two_columns.csv')

sr=df['Category']
sr
# Out:
# 0              Food
# 1              Food
# 2     Entertainment
# 3               NaN
# 4         Transport
#           ...
# 76         Shopping
# 77    Entertainment
# 78             Food
# 79              NaN
# 80             Food
# Name: Category, Length: 81, dtype: str

# %%
type(sr)
# Out:
# pandas.DataFrame

# %% [markdown]
# ## Series Method

# %%
# head and tail
sr.head() # just showing the only 5 results
# Out:
# 0             Food
# 1             Food
# 2    Entertainment
# 3              NaN
# 4        Transport
# Name: Category, dtype: str

# %%
sr.head(10)
# Out:
# 0             Food
# 1             Food
# 2    Entertainment
# 3              NaN
# 4        Transport
# 5             Rent
# 6             Food
# 7         Shopping
# 8             Food
# 9             Rent
# Name: Category, dtype: str

# %%
sr.tail() # tail shows the last one results
# Out:
# 76         Shopping
# 77    Entertainment
# 78             Food
# 79              NaN
# 80             Food
# Name: Category, dtype: str

# %%
sr.tail(10) # this will show the last ten results
# Out:
# 71        Education
# 72        Utilities
# 73        Education
# 74        Transport
# 75         Shopping
# 76         Shopping
# 77    Entertainment
# 78             Food
# 79              NaN
# 80             Food
# Name: Category, dtype: str

# %%
# sample
# this gives the random one row data from the data set
sr.sample()
# Out:
# 45    Shopping
# Name: Category, dtype: str

# %%
sr.sample() # giving the random one data from the data set
# Out:
# 32    Transport
# Name: Category, dtype: str

# %%
sr.sample(10) # men randomly ten data will be shown here
# Out:
# 21             Food
# 34        Education
# 10        Utilities
# 74        Transport
# 2     Entertainment
# 5              Rent
# 26        Utilities
# 37         Shopping
# 61    Entertainment
# 45         Shopping
# Name: Category, dtype: str

# %%
# value_counts
sr.value_counts()# giving the frequency of the items
# Out:
# Category
# Food             16
# Education        13
# Entertainment    11
# Rent              9
# Shopping          9
# Utilities         9
# Transport         7
# Name: count, dtype: int64

# %%
# sort_values
import pandas as pd
df=pd.read_csv('expenses_two_columns.csv')
expense=df[['Category','Amount_PKR']]
expense
# Out:
#          Category  Amount_PKR
# 0            Food         NaN
# 1            Food       923.0
# 2   Entertainment       717.0
# 3             NaN      1289.0
# 4       Transport       270.0
# ..            ...         ...
# 76       Shopping      1179.0
# 77  Entertainment       490.0
# 78           Food       838.0
# 79            NaN      1025.0
# 80           Food       906.0
#
# [81 rows x 2 columns]

# %%
# that is the data frame question
expense.sort_values(by='Amount_PKR',ascending=False)
# Out:
#      Category  Amount_PKR
# 13       Rent     20752.0
# 5        Rent     16684.0
# 65       Rent     15489.0
# 9        Rent     13872.0
# 58       Rent     13814.0
# ..        ...         ...
# 7    Shopping         NaN
# 12       Rent         NaN
# 26  Utilities         NaN
# 35  Utilities         NaN
# 38       Rent         NaN
#
# [81 rows x 2 columns]

# %%
expense.sort_values(by='Amount_PKR',ascending=True)
# Out:
#      Category  Amount_PKR
# 66  Transport       191.0
# 4   Transport       270.0
# 32  Transport       272.0
# 40  Transport       291.0
# 74  Transport       297.0
# ..        ...         ...
# 7    Shopping         NaN
# 12       Rent         NaN
# 26  Utilities         NaN
# 35  Utilities         NaN
# 38       Rent         NaN
#
# [81 rows x 2 columns]

# %%
expense.sort_values(by='Category',ascending=False)
# Out:
#      Category  Amount_PKR
# 41  Utilities      2547.0
# 10  Utilities      2339.0
# 35  Utilities         NaN
# 33  Utilities      1850.0
# 28  Utilities      1616.0
# ..        ...         ...
# 29        NaN       375.0
# 31        NaN      1516.0
# 46        NaN      1991.0
# 48        NaN       593.0
# 79        NaN      1025.0
#
# [81 rows x 2 columns]

# %%
expense.sort_values(by='Category',ascending=False).head(10)
# Out:
#      Category  Amount_PKR
# 41  Utilities      2547.0
# 10  Utilities      2339.0
# 35  Utilities         NaN
# 33  Utilities      1850.0
# 28  Utilities      1616.0
# 26  Utilities         NaN
# 23  Utilities      2522.0
# 72  Utilities      2462.0
# 68  Utilities      2422.0
# 40  Transport       291.0

# %%
expense.sort_values(by='Category',ascending=False).tail(10)
# Out:
#      Category  Amount_PKR
# 25  Education      2172.0
# 34  Education      2496.0
# 63  Education      1164.0
# 3         NaN      1289.0
# 18        NaN       854.0
# 29        NaN       375.0
# 31        NaN      1516.0
# 46        NaN      1991.0
# 48        NaN       593.0
# 79        NaN      1025.0

# %%
type(sr)
# Out:
# pandas.Series

# %%
type(expense) # so it is dataframe
# Out:
# pandas.DataFrame

# %%
sr.sort_values(ascending=False)
# Out:
# 41    Utilities
# 10    Utilities
# 35    Utilities
# 33    Utilities
# 28    Utilities
#         ...
# 29          NaN
# 31          NaN
# 46          NaN
# 48          NaN
# 79          NaN
# Name: Category, Length: 81, dtype: str

# %%
sr.sort_values(ascending=True)
# Out:
# 55    Education
# 15    Education
# 52    Education
# 20    Education
# 22    Education
#         ...
# 29          NaN
# 31          NaN
# 46          NaN
# 48          NaN
# 79          NaN
# Name: Category, Length: 81, dtype: str

# %%
# sort_index()
expense.sort_index()
# Out:
#          Category  Amount_PKR
# 0            Food         NaN
# 1            Food       923.0
# 2   Entertainment       717.0
# 3             NaN      1289.0
# 4       Transport       270.0
# ..            ...         ...
# 76       Shopping      1179.0
# 77  Entertainment       490.0
# 78           Food       838.0
# 79            NaN      1025.0
# 80           Food       906.0
#
# [81 rows x 2 columns]

# %%
expense.sort_values(by='Category').tail(10)
# Out:
#      Category  Amount_PKR
# 35  Utilities         NaN
# 68  Utilities      2422.0
# 26  Utilities         NaN
# 3         NaN      1289.0
# 18        NaN       854.0
# 29        NaN       375.0
# 31        NaN      1516.0
# 46        NaN      1991.0
# 48        NaN       593.0
# 79        NaN      1025.0

# %%
expense.sort_values(by='Amount_PKR')
# Out:
#      Category  Amount_PKR
# 66  Transport       191.0
# 4   Transport       270.0
# 32  Transport       272.0
# 40  Transport       291.0
# 74  Transport       297.0
# ..        ...         ...
# 7    Shopping         NaN
# 12       Rent         NaN
# 26  Utilities         NaN
# 35  Utilities         NaN
# 38       Rent         NaN
#
# [81 rows x 2 columns]

# %% [markdown]
# ## Series Mathematical Function

# %%
#count
expense.count()
# Out:
# Category      74
# Amount_PKR    75
# dtype: int64

# %%
#sum/ product
print(expense['Amount_PKR'].sum()) # that is dataframe object ok
# Out:
# 193779.0

# %%
series
# Out:
# 0     2114.0
# 1        NaN
# 2        NaN
# 3      709.0
# 4     3855.0
#        ...
# 57    5729.0
# 58    3434.0
# 59    2617.0
# 60    2893.0
# 61    1065.0
# Name: Expense_PKR, Length: 62, dtype: float64

# %%
print(series.sum())
# Out:
# 175978.0

# %%
print(series.product())
# Out:
# -7.129630201011174e+191

# %%
# mean, median, mode , std, var
print(series.mean())
# Out:
# 3142.464285714286

# %%
print(series.median())
# Out:
# 3026.0

# %%
print(series.mode()) # this gives the most frequect value in the data
# Out:
# 0    1964.0
# 1    2431.0
# Name: Expense_PKR, dtype: float64

# %%
print(series.std())
# Out:
# 1512.7578543752554

# %%
print(series.var())
# Out:
# 2288436.325974026

# %%
# describe

# %%
print(series.describe())
# Out:
# count      56.000000
# mean     3142.464286
# std      1512.757854
# min      -129.000000
# 25%      2170.250000
# 50%      3026.000000
# 75%      4446.000000
# max      6464.000000
# Name: Expense_PKR, dtype: float64

# %% [markdown]
# ## Series Indexing

# %%
# indixcing
series[0]
# Out:
# np.float64(2114.0)

# %%
# Negative indexing not work on the numerical data it
# just applicable on the String data
series[-1] # will give an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\mnoma\anaconda3\envs\venv\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 series[-1]
#
# File c:\Users\mnoma\anaconda3\envs\venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
# ...

# %%
expense
# Out:
#          Category  Amount_PKR
# 0            Food         NaN
# 1            Food       923.0
# 2   Entertainment       717.0
# 3             NaN      1289.0
# 4       Transport       270.0
# ..            ...         ...
# 76       Shopping      1179.0
# 77  Entertainment       490.0
# 78           Food       838.0
# 79            NaN      1025.0
# 80           Food       906.0
#
# [81 rows x 2 columns]

# %%
expense['Category'][0:5]
# Out:
# 0             Food
# 1             Food
# 2    Entertainment
# 3              NaN
# 4        Transport
# Name: Category, dtype: str

# %%
expense['Category'][-1] # will give Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\mnoma\anaconda3\envs\venv\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 expense['Category'][-1]
#
# File c:\Users\mnoma\anaconda3\envs\venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# ...

# %%
type(expense) # ok it is dataframe
# Out:
# pandas.DataFrame

# %%
marks
# Out:
# ICT         58
# DLD         89
# ENGLISH     56
# OOP        100
# Name: Noman Marks, dtype: int64

# %% [markdown]
# ## Slicing

# %%
marks[:]
# Out:
# ICT         58
# DLD         89
# ENGLISH     56
# OOP        100
# Name: Noman Marks, dtype: int64

# %%
marks[2:]
# Out:
# ENGLISH     56
# OOP        100
# Name: Noman Marks, dtype: int64

# %%
marks[::-1]
# Out:
# OOP        100
# ENGLISH     56
# DLD         89
# ICT         58
# Name: Noman Marks, dtype: int64

# %%
marks[::2]
# Out:
# ICT        58
# ENGLISH    56
# Name: Noman Marks, dtype: int64

# %%
# fancy indexin
var.iloc[[1,3,6]]
# Out:
# Computer Science    92
# Chemistry           83
# Machine Learning    90
# Name:  Noman's Marks, dtype: int64

# %% [markdown]
# ## with Labeling

# %%
marks[['DLD','ENGLISH']]
# Out:
# DLD        89
# ENGLISH    56
# Name: Noman Marks, dtype: int64

# %% [markdown]
# ## Editing Series

# %%
# using indexing
marks['ICT']=90
marks
# Out:
# ICT         90
# DLD         89
# ENGLISH     56
# OOP        100
# 1          100
# 2          100
# Name: Noman Marks, dtype: int64

# %%
# if an index does not exist then it will add to the series
marks['Computer Science']=56
marks
# Out:
# ICT                  58
# DLD                  89
# ENGLISH              56
# OOP                 100
# Computer Science     56
# Name: Noman Marks, dtype: int64

# %%
run_ser=pd.Series([23,46,78,90,100])
run_ser
# Out:
# 0     23
# 1     46
# 2     78
# 3     90
# 4    100
# dtype: int64

# %% [markdown]
# ## Editing Through Slicing

# %%
run_ser[2:4]=[100,100]
run_ser
# Out:
# 0     23
# 1     45
# 2    100
# 3    100
# 4    123
# 5    256
# 6     23
# dtype: int64

# %% [markdown]
# ## through fancy indexing

# %%
run_ser[[1,2,3]]=[0,0,0]
run_ser
# Out:
# 0     23
# 1      0
# 2      0
# 3      0
# 4    100
# dtype: int64

# %%
run_ser[::-1]
# Out:
# 4    100
# 3      0
# 2      0
# 1      0
# 0     23
# dtype: int64

# %% [markdown]
# ## Some Series important Methods

# %%
import numpy as np
import pandas as pd

# 1. Setup a sample Series to practice on
prices = pd.Series(
    [100, 250, 100, np.nan, 50, 1200, 300],
    index=["item1", "item2", "item3", "item4", "item5", "item6", "item7"],name='Prices List'
)

# %%
print("Original Series:")
print(prices)
print("-" * 40)
# Out:
# Original Series:
# item1     100.0
# item2     250.0
# item3     100.0
# item4       NaN
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
# 2. agg (Aggregate one or more operations)
# Finds multiple summary statistics at once

print("Agg:")
print(prices.agg(["min", "max", "mean"]))
print("-" * 40)
# Out:
# Agg:
# min       50.000000
# max     1200.000000
# mean     333.333333
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
# 3. astype (Change data type)
# Converts data type (e.g., changing float to string or integer)
# Note: We drop NaN first because integers can't hold standard NaNs
print("Astype:")
print(prices.dropna().astype(int))
print("-" * 40)
# Out:
# Astype:
# item1     100
# item2     250
# item3     100
# item5      50
# item6    1200
# item7     300
# Name: Prices List, dtype: int64
# ----------------------------------------

# %%
print("Between")
print(prices.between(100,300))
print('*' *40)
# Out:
# Between
# item1     True
# item2     True
# item3     True
# item4    False
# item5    False
# item6    False
# item7     True
# Name: Prices List, dtype: bool
# ****************************************

# %%
# i can also do the fancy indexing on that
print("Between")
print(prices[prices.between(100,300)])
print('*' *40)
# Out:
# Between
# item1    100.0
# item2    250.0
# item3    100.0
# item7    300.0
# Name: Prices List, dtype: float64
# ****************************************

# %%
prices
# Out:
# item1     100.0
# item2     250.0
# item3     100.0
# item4       NaN
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64

# %%
# 5. clip (Cap outliers or extreme values)
# Forces values below 100 to become 100, and values above 500 to become 500
print("Clip")
print(prices.clip(lower=100,upper=500))
print("-"*40)
# Out:
# Clip
# item1    100.0
# item2    250.0
# item3    100.0
# item4      NaN
# item5    100.0
# item6    500.0
# item7    300.0
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
# 6. drop_duplicates (Remove repeating values)
# Removes the second '100' in our dataset
print("Drop_duplicates:")
print(prices.drop_duplicates())
print("-" * 40)
# Out:
# Drop_duplicates:
# item1     100.0
# item2     250.0
# item4       NaN
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
# 7. dropna (Remove missing values)
# Drops the NaN value at 'item4'
print("Dropna:")
print(prices.dropna())
print("-" * 40)
# Out:
# Dropna:
# item1     100.0
# item2     250.0
# item3     100.0
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
prices
# Out:
# item1     100.0
# item2     250.0
# item3     100.0
# item4       NaN
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64

# %%
# 8. fillna (Replace missing values)
# Replaces the NaN at 'item4' with a default value like 0
print(prices.fillna(0)) # see the item numner 04
# Out:
# item1     100.0
# item2     250.0
# item3     100.0
# item4       0.0
# item5      50.0
# item6    1200.0
# item7     300.0
# Name: Prices List, dtype: float64

# %%
# 9. filter (Filter by index labels)
# Searches and keeps rows where the index label matches a pattern
print("Filter:")
print(prices.filter(like="item6"))
# Out:
# Filter:
# item6    1200.0
# Name: Prices List, dtype: float64

# %%
# 10. iloc (Select by integer position)
# Grabs the value at index position 1 (the 2nd element
print("iloc")
print(prices.iloc[1])
# Out:
# iloc
# 250.0

# %%
# 11. isnull (Check for missing values)
# Returns True if a value is NaN, False otherwise
print("isnull:")
print(prices.isnull())
print("-" * 40)
# Out:
# isnull:
# item1    False
# item2    False
# item3    False
# item4     True
# item5    False
# item6    False
# item7    False
# Name: Prices List, dtype: bool
# ----------------------------------------

# %%
# printing the exact null value through fancy indexing
print("isnull:")
print(prices[prices.isnull()]) 
print("-" * 40)
# Out:
# isnull:
# item4   NaN
# Name: Prices List, dtype: float64
# ----------------------------------------

# %%
# 12. map (Transform values using a dictionary or function)
# Modifies every value in the Series (e.g., adding a currency sign)
print("map:")
print(prices.map(lambda x: f"PKR {x}"))
# lambda argument : expression
# Out:
# map:
# item1     PKR 100.0
# item2     PKR 250.0
# item3     PKR 100.0
# item4       PKR nan
# item5      PKR 50.0
# item6    PKR 1200.0
# item7     PKR 300.0
# Name: Prices List, dtype: str

# %%
s = pd.Series(["cat", "dog", np.nan, "rabbit"])
s
# Out:
# 0       cat
# 1       dog
# 2       NaN
# 3    rabbit
# dtype: str

# %%
# map accepts a dict or a Series. Values that are not found 
# in the dict are converted to NaN,unless the dict has a defaultvalue (e.g. defaultdict):
s.map({"cat": "kitten", "dog": "puppy"})
# Out:
# 0    kitten
# 1     puppy
# 2       NaN
# 3       NaN
# dtype: str

# %%
# It also accepts a function:
s.map("i am a {}".format)
# Out:
# 0       i am a cat
# 1       i am a dog
# 2       i am a nan
# 3    i am a rabbit
# dtype: str

# %%
# It also accepts a function:
s.dropna().map("i am a {}".format,na_action="ignore")
# Out:
# 0       i am a cat
# 1       i am a dog
# 3    i am a rabbit
# dtype: str

# %%
# It also accepts a function:
s.dropna().map("i am a {}".format)
# Out:
# 0       i am a cat
# 1       i am a dog
# 3    i am a rabbit
# dtype: str

# %% [markdown]
# ## Series with python Functionalities

# %%
# len
print(len(prices))
# Out:
# 7

# %%
print(type(prices))
# Out:
# <class 'pandas.Series'>

# %%
print(dir(prices))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__r
# ...

# %%
marks
# Out:
# ICT                  58
# DLD                  89
# ENGLISH              56
# OOP                 100
# Computer Science     56
# Name: Noman Marks, dtype: int64

# %%
sorted(marks)
# Out:
# [56, 56, 58, 89, 100]

# %%
max(marks)
# Out:
# 100

# %%
min(marks)
# Out:
# 56

# %%
# type conversion
tuple(marks)
# Out:
# (58, 89, 56, 100, 56)

# %%
list(marks)
# Out:
# [58, 89, 56, 100, 56]

# %%
dict(marks)
# Out:
# {'ICT': np.int64(58),
#  'DLD': np.int64(89),
#  'ENGLISH': np.int64(56),
#  'OOP': np.int64(100),
#  'Computer Science': np.int64(56)}

# %%
# membership operator 
# in is a membership operator and works on the index
if 'ENGLISH' in marks:
    print(f"yes English is in the dict")
# Out:
# yes English is in the dict

# %%
# if we want to apply this concept on the values then
if 58 in marks.values:
    print(f" These marks are the ICT Subject")
# Out:
#  These marks are the ICT Subject

# %%
# looping
for i in marks:
    print(i)
# Out:
# 58
# 89
# 56
# 100
# 56

# %%
# Arithimatic Operator(Broadcasting)
100 - marks
# Out:
# ICT                 42
# DLD                 11
# ENGLISH             44
# OOP                  0
# Computer Science    44
# Name: Noman Marks, dtype: int64

# %%
100 * marks
# Out:
# ICT                  5800
# DLD                  8900
# ENGLISH              5600
# OOP                 10000
# Computer Science     5600
# Name: Noman Marks, dtype: int64

# %%
100 / marks
# Out:
# ICT                 1.724138
# DLD                 1.123596
# ENGLISH             1.785714
# OOP                 1.000000
# Computer Science    1.785714
# Name: Noman Marks, dtype: float64

# %%
100 % marks
# Out:
# ICT                 42
# DLD                 11
# ENGLISH             44
# OOP                  0
# Computer Science    44
# Name: Noman Marks, dtype: int64

# %%
# relational operators
marks >=50
# Out:
# ICT                 True
# DLD                 True
# ENGLISH             True
# OOP                 True
# Computer Science    True
# Name: Noman Marks, dtype: bool

# %%
marks[marks>=50] # Boolean indexing
# Out:
# ICT                  58
# DLD                  89
# ENGLISH              56
# OOP                 100
# Computer Science     56
# Name: Noman Marks, dtype: int64

# %%
marks[marks%2!=0]
# Out:
# DLD    89
# Name: Noman Marks, dtype: int64

# %%
marks[(marks >=20) & (marks <=80)]
# Out:
# ICT                 58
# ENGLISH             56
# Computer Science    56
# Name: Noman Marks, dtype: int64

# %% [markdown]
# ## Ploting Graph

# %%
marks.plot()
# Out:
# <Axes: >

# %%
series.plot()
# Out:
# <Axes: >

# %%
prices.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Prices List'>

# %%
sr.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
sr.value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
prices.value_counts().plot(kind="pie")
# Out:
# <Axes: >
